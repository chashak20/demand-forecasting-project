# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# Deep Learning ke liye
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# Preprocessing ke liye
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

plt.style.use('seaborn-v0_8-whitegrid')

print('✅ Libraries imported!')
print(f'✅ TensorFlow version: {tf.__version__}')
# Out:
# ✅ Libraries imported!
# ✅ TensorFlow version: 2.21.0

# %%
DATA_PATH = r"C:\demand_Forecasting\data" + "\\"

try:
    df = pd.read_csv(DATA_PATH + 'ca1_foods_daily.csv', parse_dates=['date'])
    print('✅ ca1_foods_daily.csv load ho gayi!')
except FileNotFoundError:
    print('⚠️  ca1_foods_daily.csv nahi mili — seedha bana raha hoon...')
    sales = pd.read_csv(DATA_PATH + 'sales_train_evaluation.csv')
    cal   = pd.read_csv(DATA_PATH + 'calendar.csv')
    id_cols  = ['id','item_id','dept_id','cat_id','store_id','state_id']
    day_cols = [c for c in sales.columns if c.startswith('d_')]
    long = sales[sales['store_id']=='CA_1'].melt(
        id_vars=id_cols, value_vars=day_cols, var_name='d', value_name='sales')
    long = long.merge(cal[['d','date']], on='d', how='left')
    long['date'] = pd.to_datetime(long['date'])
    df = long[long['cat_id']=='FOODS'].groupby('date')['sales'].sum().reset_index()
    df.to_csv(DATA_PATH + 'ca1_foods_daily.csv', index=False)
    print('✅ Data banaya!')

df = df.set_index('date').asfreq('D')
print(f'Shape      : {df.shape}')
print(f'Date range : {df.index.min()} → {df.index.max()}')
df.head()
# Out:
# ✅ ca1_foods_daily.csv load ho gayi!
# Shape      : (1941, 1)
# Date range : 2011-01-29 00:00:00 → 2016-05-22 00:00:00
#             sales
# date
# 2011-01-29   3239
# 2011-01-30   3137
# 2011-01-31   2008
# 2011-02-01   2258
# 2011-02-02   2032

# %%
# Scale karo 0 to 1 range mein
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df[['sales']])

print(f'Original data range  : {df["sales"].min():.0f} → {df["sales"].max():.0f}')
print(f'Scaled data range    : {scaled_data.min():.4f} → {scaled_data.max():.4f}')
print('✅ Data scaled!')
# Out:
# Original data range  : 0 → 5016
# Scaled data range    : 0.0000 → 1.0000
# ✅ Data scaled!

# %%
def create_sequences(data, lookback=30):
    """
    lookback = kitne past days dekh ke predict karna hai
    """
    X, y = [], []
    for i in range(lookback, len(data)):
        X.append(data[i-lookback:i, 0])   # past 'lookback' days
        y.append(data[i, 0])               # next day
    return np.array(X), np.array(y)

LOOKBACK  = 30    # past 30 days dekh ke predict karo
TEST_DAYS = 28

X_all, y_all = create_sequences(scaled_data, LOOKBACK)

# Train / Test split
X_train = X_all[:-TEST_DAYS]
y_train = y_all[:-TEST_DAYS]
X_test  = X_all[-TEST_DAYS:]
y_test  = y_all[-TEST_DAYS:]

# LSTM ke liye reshape: (samples, timesteps, features)
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test  = X_test.reshape(X_test.shape[0],   X_test.shape[1],  1)

print(f'X_train shape : {X_train.shape}  → (samples, timesteps, features)')
print(f'y_train shape : {y_train.shape}')
print(f'X_test shape  : {X_test.shape}')
print(f'y_test shape  : {y_test.shape}')
print('✅ Sequences ready!')
# Out:
# X_train shape : (1883, 30, 1)  → (samples, timesteps, features)
# y_train shape : (1883,)
# X_test shape  : (28, 30, 1)
# y_test shape  : (28,)
# ✅ Sequences ready!

# %%
def build_lstm_model(lookback):
    model = Sequential([
        # Layer 1: LSTM — 64 units, sequences return karo
        LSTM(64, return_sequences=True, input_shape=(lookback, 1)),
        Dropout(0.2),    # Overfitting rokne ke liye

        # Layer 2: LSTM — 32 units
        LSTM(32, return_sequences=False),
        Dropout(0.2),

        # Output Layer: 1 value predict karo
        Dense(16, activation='relu'),
        Dense(1)
    ])

    model.compile(
        optimizer='adam',
        loss='mean_squared_error'
    )
    return model

model = build_lstm_model(LOOKBACK)
model.summary()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 30, 64)              │          16,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 30, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 29,857 (116.63 KB)
#  Trainable params: 29,857 (116.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# EarlyStopping — agar improvement band ho jaaye toh ruk jao
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,          # 10 epochs tak improvement nahi → stop
    restore_best_weights=True
)

print('🔄 LSTM training shuru ho rahi hai...')
print('   (5-10 min lag sakta hai — chai pee lo ☕)')
print()

history = model.fit(
    X_train, y_train,
    epochs          = 100,
    batch_size      = 32,
    validation_split= 0.1,    # 10% validation ke liye
    callbacks       = [early_stop],
    verbose         = 1
)

print()
print(f'✅ Training complete!')
print(f'   Total epochs run : {len(history.history["loss"])}')
print(f'   Final train loss : {history.history["loss"][-1]:.6f}')
print(f'   Final val loss   : {history.history["val_loss"][-1]:.6f}')
# Out:
# 🔄 LSTM training shuru ho rahi hai...
#    (5-10 min lag sakta hai — chai pee lo ☕)
#
# Epoch 1/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 14s 75ms/step - loss: 0.0544 - val_loss: 0.0158
# Epoch 2/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0211 - val_loss: 0.0157
# Epoch 3/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.0198 - val_loss: 0.0161
# Epoch 4/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 0.0188 - val_loss: 0.0176
# Epoch 5/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - loss: 0.0196 - val_loss: 0.0158
# Epoch 6/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 0.0187 - val_loss: 0.0156
# Epoch 7/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.0190 - val_loss: 0.0157
# Epoch 8/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 0.0187 - val_loss: 0.0156
# Epoch 9/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0177 - val_loss: 0.0157
# Epoch 10/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 0.0193 - val_loss: 0.0183
# Epoch 11/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0177 - val_loss: 0.0167
# Epoch 12/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 0.0179 - val_loss: 0.0155
# Epoch 13/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.0176 - val_loss: 0.0156
# Epoch 14/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.0181 - val_loss: 0.0155
# Epoch 15/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - loss: 0.0186 - val_loss: 0.0157
# Epoch 16/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - loss: 0.0183 - val_loss: 0.0177
# Epoch 17/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 0.0172 - val_loss: 0.0153
# Epoch 18/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 0.0171 - val_loss: 0.0153
# Epoch 19/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 0.0171 - val_loss: 0.0149
# Epoch 20/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - loss: 0.0168 - val_loss: 0.0150
# Epoch 21/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 0.0162 - val_loss: 0.0157
# Epoch 22/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - loss: 0.0162 - val_loss: 0.0169
# Epoch 23/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 0.0163 - val_loss: 0.0147
# Epoch 24/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - loss: 0.0158 - val_loss: 0.0166
# Epoch 25/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - loss: 0.0157 - val_loss: 0.0158
# Epoch 26/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0157 - val_loss: 0.0147
# Epoch 27/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - loss: 0.0164 - val_loss: 0.0200
# Epoch 28/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 0.0160 - val_loss: 0.0145
# Epoch 29/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0152 - val_loss: 0.0151
# Epoch 30/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - loss: 0.0149 - val_loss: 0.0198
# Epoch 31/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 0.0157 - val_loss: 0.0159
# Epoch 32/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0149 - val_loss: 0.0166
# Epoch 33/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.0093 - val_loss: 0.0084
# Epoch 34/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0082 - val_loss: 0.0073
# Epoch 35/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0078 - val_loss: 0.0069
# Epoch 36/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0072 - val_loss: 0.0065
# Epoch 37/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0066 - val_loss: 0.0071
# Epoch 38/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 0.0067 - val_loss: 0.0063
# Epoch 39/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 40/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0066 - val_loss: 0.0076
# Epoch 41/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.0065 - val_loss: 0.0064
# Epoch 42/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0064 - val_loss: 0.0062
# Epoch 43/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0065 - val_loss: 0.0080
# Epoch 44/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0063 - val_loss: 0.0069
# Epoch 45/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 0.0069 - val_loss: 0.0067
# Epoch 46/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0060 - val_loss: 0.0074
# Epoch 47/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0058 - val_loss: 0.0062
# Epoch 48/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 0.0062 - val_loss: 0.0075
# Epoch 49/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0058 - val_loss: 0.0061
# Epoch 50/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 0.0057 - val_loss: 0.0071
# Epoch 51/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 0.0057 - val_loss: 0.0067
# Epoch 52/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 0.0056 - val_loss: 0.0064
# Epoch 53/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0059 - val_loss: 0.0062
# Epoch 54/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0060 - val_loss: 0.0063
# Epoch 55/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 0.0056 - val_loss: 0.0066
# Epoch 56/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 0.0060 - val_loss: 0.0068
# Epoch 57/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0056 - val_loss: 0.0065
# Epoch 58/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0055 - val_loss: 0.0059
# Epoch 59/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0053 - val_loss: 0.0065
# Epoch 60/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0052 - val_loss: 0.0066
# Epoch 61/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0059 - val_loss: 0.0070
# Epoch 62/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0055 - val_loss: 0.0065
# Epoch 63/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0053 - val_loss: 0.0069
# Epoch 64/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.0056 - val_loss: 0.0063
# Epoch 65/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0055 - val_loss: 0.0063
# Epoch 66/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 0.0053 - val_loss: 0.0062
# Epoch 67/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 0.0052 - val_loss: 0.0063
# Epoch 68/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 0.0052 - val_loss: 0.0063
#
# ✅ Training complete!
#    Total epochs run : 68
#    Final train loss : 0.005184
#    Final val loss   : 0.006297

# %%
# Predict karo
pred_scaled = model.predict(X_test)

# Inverse transform — scaled values wapis original scale mein
pred_lstm = scaler.inverse_transform(pred_scaled).flatten()
actual    = scaler.inverse_transform(y_test.reshape(-1, 1)).flatten()

# Negative values 0 karo
pred_lstm = np.maximum(pred_lstm, 0)

print('✅ Predictions ready!')
print(f'First prediction : {pred_lstm[0]:.1f}')
print(f'Actual value     : {actual[0]:.1f}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step
# ✅ Predictions ready!
# First prediction : 2777.1
# Actual value     : 2893.0

# %%
# Test dates nikalo
test_dates = df.index[-TEST_DAYS:]
train_dates_plot = df.index[-TEST_DAYS-90:-TEST_DAYS]  # last 90 days of train
train_actual_plot = scaler.inverse_transform(
    scaled_data[-TEST_DAYS-90:-TEST_DAYS]).flatten()

plt.figure(figsize=(16, 5))
plt.plot(train_dates_plot, train_actual_plot,
         color='steelblue', label='Train (last 90 days)')
plt.plot(test_dates, actual,
         color='orange', linewidth=2, label='Actual')
plt.plot(test_dates, pred_lstm,
         color='red', linewidth=2, linestyle='--', label='LSTM Forecast')
plt.axvline(x=test_dates[0], color='gray', linestyle=':', alpha=0.7)
plt.title('LSTM — Forecast vs Actual (28 days)', fontsize=13, fontweight='bold')
plt.legend()
plt.ylabel('Sales')
plt.tight_layout()
plt.savefig('lstm_forecast.png', dpi=150, bbox_inches='tight')
plt.show()
print('💾 lstm_forecast.png saved!')
# Out:
# 💾 lstm_forecast.png saved!

# %%
mae  = mean_absolute_error(actual, pred_lstm)
rmse = np.sqrt(mean_squared_error(actual, pred_lstm))
mape = np.mean(np.abs((actual - pred_lstm) / actual)) * 100

lstm_result = {'Model': 'LSTM', 'MAE': round(mae,2),
               'RMSE': round(rmse,2), 'MAPE': round(mape,2)}

print('📊 LSTM Model')
print(f'   MAE  : {mae:.2f}')
print(f'   RMSE : {rmse:.2f}')
print(f'   MAPE : {mape:.2f}%')
# Out:
# 📊 LSTM Model
#    MAE  : 308.88
#    RMSE : 362.43
#    MAPE : 9.13%
